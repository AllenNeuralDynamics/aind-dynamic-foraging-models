# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import logging
logging.basicConfig(
    level=logging.INFO, 
    format='%(filename)s:%(lineno)d - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

SESSION_KEYS = ["subject_id", "session_date"]

import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'
import seaborn as sns

from aind_analysis_arch_result_access.han_pipeline import get_session_table, get_mle_model_fitting
from aind_analysis_arch_result_access.util.s3 import get_s3_pkl, get_s3_json

import aind_dynamic_foraging_population_analysis

# from aind_dynamic_foraging_population_analysis.model_comparison import (
#     get_all_model_metrics,
#     enrich_with_df_session,
# )

# %%
def get_all_model_metrics(
    use_cache=True, cache_path="~/capsule/data/df_model_fitting_all.pkl"
):
    """Get all model metrics from either cache or result access API.

    Parameters
    ----------
    use_cache : bool, optional
        Whether to use cached data, by default True
        If true, it will load data from the cache. If cache does not exist
           or is invalid, it will fetch data from the API.
        If False, it will fetch data from the API and update the cache_path.
    cache_path : str, optional
        Cache path, by default "~/capsule/data/df_model_fitting_all.pkl"
    """

    if use_cache:
        try:
            logger.info(f"Trying to load data from cache: {cache_path}...")
            df_model_fitting = pd.read_pickle(cache_path)
            logger.info(f"{len(df_model_fitting)} rows loaded from cache.")
            return df_model_fitting
        except Exception as e:
            logger.warning(f"Cache not found or invalid: {e}. Fetching from API.")

    # Fetch from result access API
    logger.info("Fetching data from result access API...")
    df_model_fitting = get_mle_model_fitting(
        from_custom_query={"status": "success"},
        if_include_latent_variables=False,
        paginate_settings={"paginate": True, "paginate_batch_size": 5000},
    )
    df_model_fitting.to_pickle(cache_path)
    logger.info(f"{len(df_model_fitting)} rows fetched from API and saved to cache.")
    return df_model_fitting


def enrich_with_df_session(df, selected_fields):
    """Enrich any df with session information from get_session_table.

    Parameters
    ----------
    df: pd.DataFrame
        Any dataFrame containing SESSION_KEYS (["subject_id", "session_date"])
    selected_fields: list of str
        Fields to merge from session table.

    Returns
    -------
    pd.DataFrame
        Enriched DataFrame with selected session information.
    """
    logger.info("Fetching session table...")
    df_session = get_session_table()

    logger.info("Merging model fitting data with session data...")
    # Merge in session metadata
    df_session["session_date"] = df_session["session_date"].astype("str")
    df_enriched = df.merge(
        df_session[SESSION_KEYS + selected_fields],
        on=SESSION_KEYS,
        how="left",
    )
    return df_enriched

# %%
df_model_fitting = get_all_model_metrics(use_cache=True, 
                                         cache_path=os.path.expanduser("~/capsule/results/df_model_fitting_all.pkl"))
df_model_fitting = enrich_with_df_session(
    df_model_fitting,
    selected_fields=[
        "nwb_suffix",
        "curriculum_name",
        "curriculum_version_group",
        "current_stage_actual",
    ],
)

# %%
df_model_fitting.columns

# %%
df_model_fitting['current_stage_actual'].value_counts()

# %%
df_model_fitting['curriculum_name'].value_counts()

# %% [markdown]
# ## compare model fit

# %%
# load pre-saved model fit results
df_model_fitting_relevant = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting_relevant_250714.pkl')

# %%
# load fitted hattori, bari, foraging results
df_compare = df_model_fitting_relevant[df_model_fitting_relevant["current_stage_actual"].isin(['STAGE_FINAL', 'GRADUATED'])]

df_model_fitting_hattori = df_compare[df_compare["agent_alias"] == 'QLearning_L2F1_softmax'].sort_values(["subject_id", "session_date"])
df_model_fitting_bari = df_compare[df_compare["agent_alias"] == 'QLearning_L1F1_CK1_softmax'].sort_values(["subject_id", "session_date"])
df_model_fitting_foraging = df_compare[df_compare["agent_alias"] == 'ForagingCompareThreshold'].sort_values(["subject_id", "session_date"])

# %%
# load fitted ctt_avg results
# df_model_fitting_ctt_avg = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTAvg-251014.pkl')
df_model_fitting_ctt_avg = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTAvg-251018-rho_only.pkl')

# %%
# # load fitted ctt_avg results: archived

# df_model_fitting_ctt_avg_uncoupled_baiting = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTAvg-251007-uncoupled_baiting.pkl')
# df_model_fitting_ctt_avg_coupled_baiting = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTAvg-251007-coupled_baiting.pkl')
# df_model_fitting_ctt_avg_uncoupled_no_baiting_0_322 = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTAvg-251007-uncoupled_no_baiting-0_322.pkl')
# df_model_fitting_ctt_avg_uncoupled_no_baiting_322_end = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTAvg-251007-uncoupled_no_baiting-322_end.pkl')

# df_model_fitting_ctt_avg_uncoupled_no_baiting = pd.concat([df_model_fitting_ctt_avg_uncoupled_no_baiting_0_322, df_model_fitting_ctt_avg_uncoupled_no_baiting_322_end], ignore_index=True)
# df_model_fitting_ctt_avg_all = pd.concat([df_model_fitting_ctt_avg_uncoupled_no_baiting, df_model_fitting_ctt_avg_uncoupled_baiting, df_model_fitting_ctt_avg_coupled_baiting], ignore_index=True).sort_values(["subject_id", "session_date"])

# %%
# load fitted ctt_mean_reset results
df_model_fitting_ctt_mean_reset = pd.read_pickle('/root/capsule/analysis_result/df_model_fitting-CTTMeanReset-251014.pkl')

# %%
metric = 'log_likelihood'

task_types = ['Uncoupled Without Baiting', 'Uncoupled Baiting', 'Coupled Baiting']


model_1 = 'Bari'
df_model_1 = df_model_fitting_bari
# model_1 = 'Hattori'
# df_model_1 = df_model_fitting_hattori
# model_1 = 'Foraging'
# df_model_1 = df_model_fitting_foraging

model_2 = 'CTTAvg'
df_model_2 = df_model_fitting_ctt_avg
# model_2 = 'CTTMeanReset'
# df_model_2 = df_model_fitting_ctt_mean_reset
# model_2 = 'Hattori'
# df_model_2 = df_model_fitting_hattori
# model_2 = 'Bari'
# df_model_2 = df_model_fitting_bari


for task_type in task_types:
    print(f"Task: {task_type}")

    df_model_1_task = df_model_1[df_model_1['curriculum_name'] == task_type]
    df_model_2_task = df_model_2[df_model_2['curriculum_name'] == task_type]

    # Get sessions where both models are present based on df_model_2_task nwb_name
    df_model_2_task_selected = df_model_2_task[df_model_2_task['nwb_name'].isin(df_model_1_task['nwb_name'])]
    df_model_1_task_selected = df_model_1_task[df_model_1_task['nwb_name'].isin(df_model_2_task_selected['nwb_name'])]

    print(f"  Model 1 ({model_1}) sessions: {len(df_model_1_task_selected)}")
    print(f"  Model 2 ({model_2}) sessions: {len(df_model_2_task_selected)}")

    # scatter plot of model_1 vs model_2 using the metric
    plt.figure(figsize=(8, 8))

    # where model_1 > model_2
    greater_ids = df_model_1_task_selected[metric].values > df_model_2_task_selected[metric].values

    # Perform paired two-sample t-test
    t_statistic, p_value = stats.ttest_rel(df_model_1_task_selected[metric].values, df_model_2_task_selected[metric].values)
    print(f"  Paired t-test: t-statistic = {t_statistic:.4f}, p-value = {p_value:.4e}")

    plt.scatter(
        df_model_1_task_selected[greater_ids][metric],
        df_model_2_task_selected[greater_ids][metric],
        alpha=0.5,
        color='red',
        s=1,
        label=f"{model_1} > {model_2}: {greater_ids.sum()} sessions",
    )
    plt.scatter(
        df_model_1_task_selected[~greater_ids][metric],
        df_model_2_task_selected[~greater_ids][metric],
        alpha=0.5,
        color='blue',
        s=1,
        label=f"{model_1} <= {model_2}: {(~greater_ids).sum()} sessions",
    )
    # add a diagonal line for reference
    max_value = max(df_model_1_task_selected[metric].max(), df_model_2_task_selected[metric].max())
    min_value = min(df_model_1_task_selected[metric].min(), df_model_2_task_selected[metric].min())
    plt.plot([min_value, max_value], [min_value, max_value], color='k', linestyle='--', lw=2)

    plt.grid()
    plt.xlabel(model_1)
    plt.ylabel(model_2)
    plt.title(f"{task_type}:{model_2} vs.{model_1}")
    plt.legend()

# %%
# get fitted params hist

fitted_rhos = []
for _, row in df_model_fitting_ctt_avg.iterrows():
    fitted_rhos.append(row['params']['learn_rate'])


plt.hist(fitted_rhos, bins='auto')
# Out:
# (array([346., 138., 112., 146., 180., 243., 302., 321., 327., 408., 410.,
#         399., 367., 367., 324., 298., 261., 233., 205., 185., 137., 142.,
#         104.,  92.,  85.,  63.,  46.,  54.,  52.,  41.,  33.,  28.,  21.,
#          24.,  15.,  17.,  19.,  15.,  16.,   6.,   9.,   5.,   3.,   6.,
#          66.]),
#  array([0.        , 0.02222222, 0.04444444, 0.06666667, 0.08888889,
#         0.11111111, 0.13333333, 0.15555556, 0.17777778, 0.2       ,
#         0.22222222, 0.24444444, 0.26666667, 0.28888889, 0.31111111,
#         0.33333333, 0.35555556, 0.37777778, 0.4       , 0.42222222,
#         0.44444444, 0.46666667, 0.48888889, 0.51111111, 0.53333333,
#         0.55555556, 0.57777778, 0.6       , 0.62222222, 0.64444444,
#         0.66666667, 0.68888889, 0.71111111, 0.73333333, 0.75555556,
#         0.77777778, 0.8       , 0.82222222, 0.84444444, 0.86666667,
#         0.88888889, 0.91111111, 0.93333333, 0.95555556, 0.97777778,
#         1.        ]),
# ...

# %% [markdown]
# ### previous version, no task type breakdown

# %%
# for a given metric, compare model fit across two models using scatter plots
from cProfile import label
from botocore import session

# df_compare = df_model_fitting.copy()
df_compare = df_model_fitting[df_model_fitting["current_stage_actual"].isin(['STAGE_FINAL', 'GRADUATED'])]


model_1 = 'QLearning_L2F1_softmax'  # Hattori
# model_1 = 'QLearning_L1F1_CK1_softmax'  # Bari

model_2 = 'ForagingCompareThreshold'
# model_2 = 'QLearning_L2F1_softmax'  # Hattori
# model_2 = 'QLearning_L1F1_CK1_softmax'  # Bari


metrics = [
    "log_likelihood",
    "AIC",
    "BIC",
    "prediction_accuracy_10-CV_test",
]
# metric = "log_likelihood"
# metric = "AIC"
# metric = "BIC"
# metric = 'prediction_accuracy_10-CV_test'


for metric in metrics:
    # for a given metric, compare model fit across two models using scatter plots
    # Filter to sessions that have both models
    df_model_1 = df_compare[df_compare["agent_alias"] == model_1].sort_values(["subject_id", "session_date"])
    df_model_2 = df_compare[df_compare["agent_alias"] == model_2].sort_values(["subject_id", "session_date"])

    # Get sessions where both models are present
    session_counts = (
        df_compare[df_compare["agent_alias"].isin([model_1, model_2])]
        .groupby(SESSION_KEYS)["agent_alias"]
        .nunique()
    )
    sessions_with_both = session_counts[session_counts == 2].index

    # Subset data for only those sessions
    df_model_1_both = df_model_1[df_model_1.set_index(SESSION_KEYS).index.isin(sessions_with_both)]
    df_model_2_both = df_model_2[df_model_2.set_index(SESSION_KEYS).index.isin(sessions_with_both)]

    # scatter plot of model_1 vs model_2 using the metric
    plt.figure(figsize=(8, 8))

    # where model_1 > model_2
    greater_ids = df_model_1_both[metric].values > df_model_2_both[metric].values

    plt.scatter(
        df_model_1_both[greater_ids][metric],
        df_model_2_both[greater_ids][metric],
        alpha=0.5,
        color='red',
        s=1,
        label=f"{model_1} > {model_2}: {greater_ids.sum()} sessions",
    )
    plt.scatter(
        df_model_1_both[~greater_ids][metric],
        df_model_2_both[~greater_ids][metric],
        alpha=0.5,
        color='blue',
        s=1,
        label=f"{model_1} <= {model_2}: {(~greater_ids).sum()} sessions",
    )
    # add a diagonal line for reference
    max_value = max(df_model_1_both[metric].max(), df_model_2_both[metric].max())
    min_value = min(df_model_1_both[metric].min(), df_model_2_both[metric].min())
    plt.plot([min_value, max_value], [min_value, max_value], color='k', linestyle='--', lw=2)

    plt.grid()
    plt.xlabel(model_1)
    plt.ylabel(model_2)
    plt.title(f"Comparison of {model_1} and {model_2} using {metric}")
    plt.legend()

# %% [markdown]
# # analyze fitted parameters

# %% [markdown]
# ### all sessions for an agent

# %%
# get a specific model
agent_alias = 'ForagingCompareThreshold'
# agent_alias = 'QLearning_L2F1_softmax'  # Hattori
# agent_alias = 'QLearning_L1F1_CK1_softmax'  # Bari

df_agent_all = df_model_fitting[df_model_fitting["agent_alias"] == agent_alias].sort_values(["subject_id", "session_date"])
df_agent_all.head()

# %%
# iterate over rows to get all fitted parameters and their values
fitted_params_agent_all = {
    param_name: [] for param_name in df_agent_all['params'].iloc[0].keys()
}
for index, row in df_agent_all.iterrows():
    for param_name, param_value in row['params'].items():
        fitted_params_agent_all[param_name].append(param_value)

# convert to numpy array
fitted_params_agent_all = {
    param_name: np.array(param_values) for param_name, param_values in fitted_params_agent_all.items()
}

# %%
# for each parameter, plot histogram of fitted parameter values
for param_name, param_values in fitted_params_agent_all.items():
    plt.figure(figsize=(10, 5))
    sns.histplot(param_values, bins=30, kde=True)
    plt.title(f"Distribution of {param_name} for {agent_alias}")
    plt.xlabel(param_name)
    plt.ylabel("Count")
    plt.grid()
    plt.tight_layout()
    plt.show()
plt.close('all')

# %%
# for each parameter pair, plot scatter plot of parameter 1 vs parameter 2
for i, (param_name_1, param_values_1) in enumerate(fitted_params_agent_all.items()):
    for j, (param_name_2, param_values_2) in enumerate(fitted_params_agent_all.items()):
        if i >= j:  # avoid duplicate pairs and self-comparison
            continue
        plt.figure(figsize=(8, 8))
        plt.scatter(param_values_1, param_values_2, alpha=0.6, s=2)
        plt.title(f"{agent_alias}: {param_name_1} vs {param_name_2}")
        plt.xlabel(param_name_1)
        plt.ylabel(param_name_2)
        plt.grid()
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### overlay breakdown based on curriculum type

# %%
# plot histogram of fitted parameters of each curriculum type
# overlay on top of each other

curriculum_names = [
    'Uncoupled Baiting',
    'Uncoupled Without Baiting',
    'Coupled Baiting'
]


for param_name, param_values in fitted_params_agent_all.items():
    plt.figure(figsize=(10, 5))
    plt.title(f"Distribution of {param_name} for {agent_alias}")
    sns.histplot(param_values, bins=30, kde=True, label='all')
    plt.xlabel(param_name)
    plt.ylabel("Count")

    for curriculum_name in curriculum_names:
        ids_curriculum = (df_agent_all['curriculum_name'] == curriculum_name).values.nonzero()[0].astype(int)
        param_value_curriculum = fitted_params_agent_all[param_name][ids_curriculum]

        sns.histplot(param_value_curriculum, bins=30, kde=True, label=curriculum_name, alpha=0.4)
    
    # plt.yscale('log')
    plt.grid()
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### overlay single subject distribution on top of all

# %%
# overlay single subject distribution on top of all
# for each parameter pair, plot scatter plot of parameter 1 vs parameter 2

subject_ids = [
    # '781370',  # uncoupled, no baiting
    # '764769',  # uncoupled, baiting
    # '776293',  # uncoupled, baiting
    '769884',  # uncoupled, baiting
]

for i, (param_name_1, param_values_1) in enumerate(fitted_params_agent_all.items()):
    for j, (param_name_2, param_values_2) in enumerate(fitted_params_agent_all.items()):
        if i >= j:  # avoid duplicate pairs and self-comparison
            continue
        plt.figure(figsize=(8, 8), dpi=150)
        plt.scatter(param_values_1, param_values_2, alpha=0.3, s=2, c='gray')

        # Overlay single subject distribution
        for subject_id in subject_ids: #df_agent_all['subject_id'].unique():
            ids_subject = (df_agent_all['subject_id'] == subject_id).values.nonzero()[0].astype(int)
            
            fitted_params_subject = {}
            fitted_params_subject[param_name_1] = param_values_1[ids_subject]
            fitted_params_subject[param_name_2] = param_values_2[ids_subject]

            # plot scatter for the subject
            # with varying color as sessions progress
            plt.scatter(
                fitted_params_subject[param_name_1],
                fitted_params_subject[param_name_2],
                alpha=0.9,
                s=2 + 2 * np.arange(len(ids_subject)),  # increase size with session count
                label=f"Subject {subject_id}",
            )
            plt.plot(
                fitted_params_subject[param_name_1],
                fitted_params_subject[param_name_2],
                alpha=0.6,
                label=f"Subject {subject_id}",
            )

        plt.title(f"{agent_alias}: {param_name_1} vs {param_name_2}")
        plt.xlabel(param_name_1)
        plt.ylabel(param_name_2)
        plt.grid()
        plt.tight_layout()
        plt.legend()
        plt.show()
plt.close('all')

# %% [markdown]
# ## single subject

# %%
# subject_id = '781370'  # uncoupled, no baiting
subject_id = '769884'  # uncoupled, baiting

df_subject = df_model_fitting[df_model_fitting["subject_id"] == subject_id]

# count number of models per subject
df_subject.value_counts("agent_alias").sort_index()

# %%
# get a specific model
# agent_alias = 'ForagingCompareThreshold'
# agent_alias = 'QLearning_L2F1_softmax'  # Hattori
agent_alias = 'QLearning_L1F1_CK1_softmax'  # Bari

df_subject_agent = df_subject[df_subject["agent_alias"] == agent_alias].sort_values("session_date")
df_subject_agent.head()

# %%
# iterate over rows to get all fitted parameters and their values

# get parameter names
fitted_params = {
    para_name: [] for para_name in df_subject_agent['params'].iloc[0].keys()
}

for index, row in df_subject_agent.iterrows():
    for param_name, param_value in row['params'].items():
        fitted_params[param_name].append(param_value)

# %%
# for each parameter, plot evolution over sessions
for param_name, param_values in fitted_params.items():
    plt.figure(figsize=(10, 5))
    plt.plot(df_subject_agent['session_date'], param_values, marker='o')
    plt.title(f"Evolution of {param_name} over sessions for subject {subject_id}")
    plt.xlabel("Session Date")
    plt.ylabel(param_name)
    plt.xticks(rotation=45)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
# for each parameter pair, plot scatter plot of parameter 1 vs parameter 2
for i, (param_name_1, param_values_1) in enumerate(fitted_params.items()):
    for j, (param_name_2, param_values_2) in enumerate(fitted_params.items()):
        if i >= j:  # avoid duplicate pairs and self-comparison
            continue
        plt.figure(figsize=(8, 8))
        plt.scatter(param_values_1, param_values_2, alpha=0.5)
        plt.title(f"{param_name_1} vs {param_name_2} for subject {subject_id}")
        plt.xlabel(param_name_1)
        plt.ylabel(param_name_2)
        plt.grid()
        plt.tight_layout()
        plt.show()
