# %% [markdown]
# # Simulation and parameter recovery of dynamic foraging task.

# %%
pip install -e /root/capsule

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
from aind_behavior_gym.dynamic_foraging.task import CoupledBlockTask, UncoupledBlockTask
from aind_dynamic_foraging_models.generative_model import ForagerCollection

# %% [markdown]
# ## Get all foragers

# %%
forager_collection = ForagerCollection()
df = forager_collection.get_all_foragers()
df.columns
# Out:
# Index(['agent_class_name', 'agent_kwargs', 'agent_alias',
#        'number_of_learning_rate', 'number_of_forget_rate', 'choice_kernel',
#        'action_selection', 'preset_name', 'n_free_params', 'params', 'forager',
#        'win_stay_lose_switch'],
#       dtype='object')

# %%
df
# Out:
#            agent_class_name  \
# 0          ForagerQLearning
# 1          ForagerQLearning
# 2          ForagerQLearning
# 3          ForagerQLearning
# 4          ForagerQLearning
# 5          ForagerQLearning
# 6          ForagerQLearning
# 7          ForagerQLearning
# 8          ForagerQLearning
# 9          ForagerQLearning
# 10         ForagerQLearning
# 11         ForagerQLearning
# 12         ForagerQLearning
# 13         ForagerQLearning
# 14         ForagerQLearning
# 15         ForagerQLearning
# 16         ForagerQLearning
# 17         ForagerQLearning
# 18         ForagerQLearning
# 19         ForagerQLearning
# 20         ForagerQLearning
# 21         ForagerQLearning
# 22         ForagerQLearning
# 23         ForagerQLearning
# 24      ForagerLossCounting
# 25      ForagerLossCounting
# 26      ForagerLossCounting
# 27      ForagerLossCounting
# 28      ForagerLossCounting
# 29      ForagerLossCounting
# 30  ForagerCompareThreshold
# 31  ForagerCompareThreshold
# 32  ForagerCompareThreshold
# 33          ForagerCTTDualQ
# 34          ForagerCTTDualQ
# 35          ForagerCTTDualQ
#
#                                          agent_kwargs  \
# 0   {'number_of_learning_rate': 1, 'number_of_forg...
# 1   {'number_of_learning_rate': 1, 'number_of_forg...
# 2   {'number_of_learning_rate': 1, 'number_of_forg...
# 3   {'number_of_learning_rate': 1, 'number_of_forg...
# 4   {'number_of_learning_rate': 1, 'number_of_forg...
# 5   {'number_of_learning_rate': 1, 'number_of_forg...
# 6   {'number_of_learning_rate': 1, 'number_of_forg...
# 7   {'number_of_learning_rate': 1, 'number_of_forg...
# 8   {'number_of_learning_rate': 1, 'number_of_forg...
# 9   {'number_of_learning_rate': 1, 'number_of_forg...
# 10  {'number_of_learning_rate': 1, 'number_of_forg...
# 11  {'number_of_learning_rate': 1, 'number_of_forg...
# 12  {'number_of_learning_rate': 2, 'number_of_forg...
# 13  {'number_of_learning_rate': 2, 'number_of_forg...
# 14  {'number_of_learning_rate': 2, 'number_of_forg...
# 15  {'number_of_learning_rate': 2, 'number_of_forg...
# 16  {'number_of_learning_rate': 2, 'number_of_forg...
# 17  {'number_of_learning_rate': 2, 'number_of_forg...
# 18  {'number_of_learning_rate': 2, 'number_of_forg...
# 19  {'number_of_learning_rate': 2, 'number_of_forg...
# 20  {'number_of_learning_rate': 2, 'number_of_forg...
# 21  {'number_of_learning_rate': 2, 'number_of_forg...
# 22  {'number_of_learning_rate': 2, 'number_of_forg...
# 23  {'number_of_learning_rate': 2, 'number_of_forg...
# 24  {'win_stay_lose_switch': False, 'choice_kernel...
# 25  {'win_stay_lose_switch': False, 'choice_kernel...
# 26  {'win_stay_lose_switch': False, 'choice_kernel...
# 27  {'win_stay_lose_switch': True, 'choice_kernel'...
# 28  {'win_stay_lose_switch': True, 'choice_kernel'...
# 29  {'win_stay_lose_switch': True, 'choice_kernel'...
# 30                          {'choice_kernel': 'none'}
# 31                      {'choice_kernel': 'one_step'}
# 32                          {'choice_kernel': 'full'}
# 33                          {'choice_kernel': 'none'}
# 34                      {'choice_kernel': 'one_step'}
# 35                          {'choice_kernel': 'full'}
#
#                         agent_alias  number_of_learning_rate  \
# 0            QLearning_L1F0_softmax                      1.0
# 1               QLearning_L1F0_epsi                      1.0
# 2        QLearning_L1F0_CK1_softmax                      1.0
# 3           QLearning_L1F0_CK1_epsi                      1.0
# 4     QLearning_L1F0_CKfull_softmax                      1.0
# 5        QLearning_L1F0_CKfull_epsi                      1.0
# 6            QLearning_L1F1_softmax                      1.0
# 7               QLearning_L1F1_epsi                      1.0
# 8        QLearning_L1F1_CK1_softmax                      1.0
# 9           QLearning_L1F1_CK1_epsi                      1.0
# 10    QLearning_L1F1_CKfull_softmax                      1.0
# 11       QLearning_L1F1_CKfull_epsi                      1.0
# 12           QLearning_L2F0_softmax                      2.0
# 13              QLearning_L2F0_epsi                      2.0
# 14       QLearning_L2F0_CK1_softmax                      2.0
# 15          QLearning_L2F0_CK1_epsi                      2.0
# 16    QLearning_L2F0_CKfull_softmax                      2.0
# 17       QLearning_L2F0_CKfull_epsi                      2.0
# 18           QLearning_L2F1_softmax                      2.0
# 19              QLearning_L2F1_epsi                      2.0
# 20       QLearning_L2F1_CK1_softmax                      2.0
# 21          QLearning_L2F1_CK1_epsi                      2.0
# 22    QLearning_L2F1_CKfull_softmax                      2.0
# 23       QLearning_L2F1_CKfull_epsi                      2.0
# 24                     LossCounting                      NaN
# 25                 LossCounting_CK1                      NaN
# 26              LossCounting_CKfull                      NaN
# 27                             WSLS                      NaN
# 28                         WSLS_CK1                      NaN
# 29                      WSLS_CKfull                      NaN
# 30         ForagingCompareThreshold                      NaN
# 31     ForagingCompareThreshold_CK1                      NaN
# 32  ForagingCompareThreshold_CKfull                      NaN
# 33                         CTTDualQ                      NaN
# 34                     CTTDualQ_CK1                      NaN
# 35                  CTTDualQ_CKfull                      NaN
#
#     number_of_forget_rate choice_kernel action_selection          preset_name  \
# 0                     0.0          none          softmax                 None
# 1                     0.0          none   epsilon-greedy      Rescorla-Wagner
# 2                     0.0      one_step          softmax                 None
# 3                     0.0      one_step   epsilon-greedy                 None
# 4                     0.0          full          softmax                 None
# 5                     0.0          full   epsilon-greedy                 None
# 6                     1.0          none          softmax                 None
# 7                     1.0          none   epsilon-greedy                 None
# 8                     1.0      one_step          softmax             Bari2019
# 9                     1.0      one_step   epsilon-greedy                 None
# 10                    1.0          full          softmax                 None
# 11                    1.0          full   epsilon-greedy                 None
# 12                    0.0          none          softmax                 None
# 13                    0.0          none   epsilon-greedy                 None
# 14                    0.0      one_step          softmax                 None
# 15                    0.0      one_step   epsilon-greedy                 None
# 16                    0.0          full          softmax                 None
# 17                    0.0          full   epsilon-greedy                 None
# 18                    1.0          none          softmax          Hattori2019
# 19                    1.0          none   epsilon-greedy                 None
# 20                    1.0      one_step          softmax                 None
# 21                    1.0      one_step   epsilon-greedy                 None
# 22                    1.0          full          softmax                 None
# 23                    1.0          full   epsilon-greedy                 None
# 24                    NaN          none              NaN                 None
# 25                    NaN      one_step              NaN                 None
# 26                    NaN          full              NaN                 None
# 27                    NaN          none              NaN  Win-Stay-Lose-Shift
# 28                    NaN      one_step              NaN                 None
# 29                    NaN          full              NaN                 None
# 30                    NaN          none              NaN   CompareToThreshold
# 31                    NaN      one_step              NaN                 None
# 32                    NaN          full              NaN                 None
# 33                    NaN          none              NaN             CTTDualQ
# 34                    NaN      one_step              NaN                 None
# 35                    NaN          full              NaN                 None
#
#     n_free_params                                             params  \
# 0               3  ParamsSymbols.learn_rate, ParamsSymbols.biasL,...
# 1               3  ParamsSymbols.learn_rate, ParamsSymbols.biasL,...
# 2               4  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 3               4  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 4               5  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 5               5  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 6               4  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 7               4  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 8               5  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 9               5  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 10              6  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 11              6  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 12              4  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 13              4  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 14              5  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 15              5  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 16              6  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 17              6  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 18              5  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 19              5  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 20              6  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 21              6  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 22              7  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 23              7  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 24              3  ParamsSymbols.loss_count_threshold_mean, Param...
# 25              4  ParamsSymbols.loss_count_threshold_mean, Param...
# 26              5  ParamsSymbols.loss_count_threshold_mean, Param...
# 27              1  ParamsSymbols.loss_count_threshold_mean (fixed...
# 28              2  ParamsSymbols.loss_count_threshold_mean (fixed...
# 29              3  ParamsSymbols.loss_count_threshold_mean (fixed...
# 30              4  ParamsSymbols.learn_rate, ParamsSymbols.biasL,...
# 31              5  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 32              6  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 33              5  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 34              6  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 35              7  ParamsSymbols.learn_rate, ParamsSymbols.forget...
#
#                                               forager win_stay_lose_switch
# 0   <aind_dynamic_foraging_models.generative_model...                  NaN
# 1   <aind_dynamic_foraging_models.generative_model...                  NaN
# 2   <aind_dynamic_foraging_models.generative_model...                  NaN
# 3   <aind_dynamic_foraging_models.generative_model...                  NaN
# 4   <aind_dynamic_foraging_models.generative_model...                  NaN
# 5   <aind_dynamic_foraging_models.generative_model...                  NaN
# 6   <aind_dynamic_foraging_models.generative_model...                  NaN
# 7   <aind_dynamic_foraging_models.generative_model...                  NaN
# 8   <aind_dynamic_foraging_models.generative_model...                  NaN
# 9   <aind_dynamic_foraging_models.generative_model...                  NaN
# 10  <aind_dynamic_foraging_models.generative_model...                  NaN
# 11  <aind_dynamic_foraging_models.generative_model...                  NaN
# 12  <aind_dynamic_foraging_models.generative_model...                  NaN
# 13  <aind_dynamic_foraging_models.generative_model...                  NaN
# 14  <aind_dynamic_foraging_models.generative_model...                  NaN
# 15  <aind_dynamic_foraging_models.generative_model...                  NaN
# 16  <aind_dynamic_foraging_models.generative_model...                  NaN
# 17  <aind_dynamic_foraging_models.generative_model...                  NaN
# 18  <aind_dynamic_foraging_models.generative_model...                  NaN
# 19  <aind_dynamic_foraging_models.generative_model...                  NaN
# 20  <aind_dynamic_foraging_models.generative_model...                  NaN
# 21  <aind_dynamic_foraging_models.generative_model...                  NaN
# 22  <aind_dynamic_foraging_models.generative_model...                  NaN
# 23  <aind_dynamic_foraging_models.generative_model...                  NaN
# 24  <aind_dynamic_foraging_models.generative_model...                False
# 25  <aind_dynamic_foraging_models.generative_model...                False
# 26  <aind_dynamic_foraging_models.generative_model...                False
# 27  <aind_dynamic_foraging_models.generative_model...                 True
# 28  <aind_dynamic_foraging_models.generative_model...                 True
# 29  <aind_dynamic_foraging_models.generative_model...                 True
# 30  <aind_dynamic_foraging_models.generative_model...                  NaN
# 31  <aind_dynamic_foraging_models.generative_model...                  NaN
# 32  <aind_dynamic_foraging_models.generative_model...                  NaN
# 33  <aind_dynamic_foraging_models.generative_model...                  NaN
# 34  <aind_dynamic_foraging_models.generative_model...                  NaN
# 35  <aind_dynamic_foraging_models.generative_model...                  NaN

# %%
df[["agent_class_name", "preset_name", "n_free_params", "params"]]
# Out:
#            agent_class_name          preset_name  n_free_params  \
# 0          ForagerQLearning                 None              3
# 1          ForagerQLearning      Rescorla-Wagner              3
# 2          ForagerQLearning                 None              4
# 3          ForagerQLearning                 None              4
# 4          ForagerQLearning                 None              5
# 5          ForagerQLearning                 None              5
# 6          ForagerQLearning                 None              4
# 7          ForagerQLearning                 None              4
# 8          ForagerQLearning             Bari2019              5
# 9          ForagerQLearning                 None              5
# 10         ForagerQLearning                 None              6
# 11         ForagerQLearning                 None              6
# 12         ForagerQLearning                 None              4
# 13         ForagerQLearning                 None              4
# 14         ForagerQLearning                 None              5
# 15         ForagerQLearning                 None              5
# 16         ForagerQLearning                 None              6
# 17         ForagerQLearning                 None              6
# 18         ForagerQLearning          Hattori2019              5
# 19         ForagerQLearning                 None              5
# 20         ForagerQLearning                 None              6
# 21         ForagerQLearning                 None              6
# 22         ForagerQLearning                 None              7
# 23         ForagerQLearning                 None              7
# 24      ForagerLossCounting                 None              3
# 25      ForagerLossCounting                 None              4
# 26      ForagerLossCounting                 None              5
# 27      ForagerLossCounting  Win-Stay-Lose-Shift              1
# 28      ForagerLossCounting                 None              2
# 29      ForagerLossCounting                 None              3
# 30  ForagerCompareThreshold   CompareToThreshold              4
# 31  ForagerCompareThreshold                 None              5
# 32  ForagerCompareThreshold                 None              6
# 33          ForagerCTTDualQ             CTTDualQ              5
# 34          ForagerCTTDualQ                 None              6
# 35          ForagerCTTDualQ                 None              7
#
#                                                params
# 0   ParamsSymbols.learn_rate, ParamsSymbols.biasL,...
# 1   ParamsSymbols.learn_rate, ParamsSymbols.biasL,...
# 2   ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 3   ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 4   ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 5   ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 6   ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 7   ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 8   ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 9   ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 10  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 11  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 12  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 13  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 14  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 15  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 16  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 17  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 18  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 19  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 20  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 21  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 22  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 23  ParamsSymbols.learn_rate_rew, ParamsSymbols.le...
# 24  ParamsSymbols.loss_count_threshold_mean, Param...
# 25  ParamsSymbols.loss_count_threshold_mean, Param...
# 26  ParamsSymbols.loss_count_threshold_mean, Param...
# 27  ParamsSymbols.loss_count_threshold_mean (fixed...
# 28  ParamsSymbols.loss_count_threshold_mean (fixed...
# 29  ParamsSymbols.loss_count_threshold_mean (fixed...
# 30  ParamsSymbols.learn_rate, ParamsSymbols.biasL,...
# 31  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 32  ParamsSymbols.learn_rate, ParamsSymbols.choice...
# 33  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 34  ParamsSymbols.learn_rate, ParamsSymbols.forget...
# 35  ParamsSymbols.learn_rate, ParamsSymbols.forget...

# %% [markdown]
# ## Initialize an agent

# %%
# Initialize the model
forager_gen = ForagerCollection().get_preset_forager("CTTDualQ", seed=42)
forager_gen.set_params(
    threshold=0.1,
    learn_rate=0.3,
    forget_rate_unchosen=0.2,
    softmax_inverse_temperature=10,
    biasL=0,
)

# forager_gen = ForagerCollection().get_preset_forager("Hattori2019", seed=42)
# forager_gen.set_params(
#     learn_rate_rew=0.2659, 
#     learn_rate_unrew=0.0643, 
#     forget_rate_unchosen=0.5541,
#     softmax_inverse_temperature=5.1442,
#     biasL=0.5099,
# )

# forager_gen = ForagerCollection().get_preset_forager("Rescorla-Wagner", seed=42)
# forager_gen.set_params(
#     biasL=0,
# )


# Create the task environment
# task = CoupledBlockTask(reward_baiting=True, num_trials=1000, seed=42)
task = UncoupledBlockTask(reward_baiting=False, num_trials=1000, seed=51)

# %% [markdown]
# ## Simulation the task

# %%
# Run the model
forager_gen.perform(task)

# Capture the results
ground_truth_params = forager_gen.params.model_dump()
ground_truth_choice_prob = forager_gen.choice_prob
# ground_truth_value = forager_gen.value
# Get the history
choice_history = forager_gen.get_choice_history()
reward_history = forager_gen.get_reward_history()

# Plot the session results
fig, axes = forager_gen.plot_session(if_plot_latent=True)

# %% [markdown]
# ## Parameter Recovery

# %%
# Fit the model to recover parameters
forager_fit = ForagerCollection().get_preset_forager("CTTDualQ", seed=42)
# forager_fit = ForagerCollection().get_preset_forager("CompareToThreshold", seed=42)
# forager_fit = ForagerCollection().get_preset_forager("Hattori2019", seed=42)
forager_fit.fit(
    choice_history,
    reward_history,
    # fit_bounds_override={"softmax_inverse_temperature": [0, 100]},
    clamp_params={
        # "biasL": 0, 
        # "softmax_inverse_temperature": 5.0
    },
    DE_kwargs=dict(
        workers=4, 
        disp=True, 
        seed=np.random.default_rng(42)
    ),
    k_fold_cross_validation=None,
)

fitting_result = forager_fit.fitting_result

# %%
# Check fitted parameters
fit_names = fitting_result.fit_settings["fit_names"]
ground_truth = [num for name, num in ground_truth_params.items() if name in fit_names]
print(f"Num of trials: {len(choice_history)}")
print(f"Fitted parameters: {fit_names}")
print(f'Ground truth: {[f"{num:.4f}" for num in ground_truth]}')
print(f'Fitted:       {[f"{num:.4f}" for num in fitting_result.x]}')
print(f"Likelihood-Per-Trial: {fitting_result.LPT}")
print(f"Prediction accuracy full dataset: {fitting_result.prediction_accuracy}\n")

# %%
# Plot the fitted session results
fig_fitting, axes = forager_fit.plot_fitted_session(if_plot_latent=True)

# Overlay the ground truth Q-values for comparison
# axes[0].plot(ground_truth_q_value[0], lw=1, color="red", ls="-", label="actual_Q(L)")
# axes[0].plot(ground_truth_q_value[1], lw=1, color="blue", ls="-", label="actual_Q(R)")
# axes[0].legend(fontsize=6, loc="upper left", bbox_to_anchor=(0.6, 1.3), ncol=4)
